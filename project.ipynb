# %%
# importing the neccesary library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] =(25,7)

# %%
df = pd.read_csv("bitcoin_dataset.csv")
df.head()
# Out:
#              Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010 0:00               0.0           2043200.0             0.0
# 1  2/18/2010 0:00               0.0           2054650.0             0.0
# 2  2/19/2010 0:00               0.0           2063600.0             0.0
# 3  2/20/2010 0:00               0.0           2074700.0             0.0
# 4  2/21/2010 0:00               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.shape
# Out:
# (2906, 24)

# %%
for col in df.columns:
    print(col)
# Out:
# Date
# btc_market_price
# btc_total_bitcoins
# btc_market_cap
# btc_trade_volume
# btc_blocks_size
# btc_avg_block_size
# btc_n_orphaned_blocks
# btc_n_transactions_per_block
# btc_median_confirmation_time
# btc_hash_rate
# btc_difficulty
# btc_miners_revenue
# btc_transaction_fees
# btc_cost_per_transaction_percent
# btc_cost_per_transaction
# btc_n_unique_addresses
# btc_n_transactions
# btc_n_transactions_total
# btc_n_transactions_excluding_popular
# btc_n_transactions_excluding_chains_longer_than_100
# btc_output_volume
# btc_estimated_transaction_volume
# btc_estimated_transaction_volume_usd

# %%
df.empty
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906 entries, 0 to 2905
# Data columns (total 24 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Date                                                 2906 non-null   object
#  1   btc_market_price                                     2906 non-null   float64
#  2   btc_total_bitcoins                                   2879 non-null   float64
#  3   btc_market_cap                                       2906 non-null   float64
#  4   btc_trade_volume                                     2885 non-null   float64
#  5   btc_blocks_size                                      2877 non-null   float64
#  6   btc_avg_block_size                                   2906 non-null   float64
#  7   btc_n_orphaned_blocks                                2906 non-null   int64
# ...

# %%
df.dtypes
# Out:
# Date                                                    object
# btc_market_price                                       float64
# btc_total_bitcoins                                     float64
# btc_market_cap                                         float64
# btc_trade_volume                                       float64
# btc_blocks_size                                        float64
# btc_avg_block_size                                     float64
# btc_n_orphaned_blocks                                    int64
# btc_n_transactions_per_block                           float64
# btc_median_confirmation_time                           float64
# btc_hash_rate                                          float64
# btc_difficulty                                         float64
# btc_miners_revenue                                     float64
# btc_transaction_fees                                   float64
# btc_cost_per_transaction_percent                       float64
# ...

# %%
df.isnull().sum()
# Out:
# Date                                                    0
# btc_market_price                                        0
# btc_total_bitcoins                                     27
# btc_market_cap                                          0
# btc_trade_volume                                       21
# btc_blocks_size                                        29
# btc_avg_block_size                                      0
# btc_n_orphaned_blocks                                   0
# btc_n_transactions_per_block                            0
# btc_median_confirmation_time                           12
# btc_hash_rate                                           0
# btc_difficulty                                         16
# btc_miners_revenue                                      0
# btc_transaction_fees                                   10
# btc_cost_per_transaction_percent                        0
# btc_cost_per_transaction                                0
# ...

# %%
df.dropna()
# Out:
#                 Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0     2/17/2010 0:00           0.00000           2043200.0    0.000000e+00
# 1     2/18/2010 0:00           0.00000           2054650.0    0.000000e+00
# 2     2/19/2010 0:00           0.00000           2063600.0    0.000000e+00
# 3     2/20/2010 0:00           0.00000           2074700.0    0.000000e+00
# 4     2/21/2010 0:00           0.00000           2085400.0    0.000000e+00
# ...              ...               ...                 ...             ...
# 2901  1/27/2018 0:00       11524.77667          16830312.5    1.939660e+11
# 2902  1/28/2018 0:00       11765.71000          16832287.5    1.980440e+11
# 2903  1/29/2018 0:00       11212.65500          16834137.5    1.887550e+11
# 2904  1/30/2018 0:00       10184.06167          16836225.0    1.714610e+11
# 2905  1/31/2018 0:00       10125.01333          16837687.5    1.704820e+11
#
#       btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# count       2906.000000        2.879000e+03    2.906000e+03      2.885000e+03
# mean         839.104218        1.151138e+07    1.344255e+10      7.398381e+07
# std         2304.972497        4.200024e+06    3.866150e+10      2.924228e+08
# min            0.000000        2.043200e+06    0.000000e+00      0.000000e+00
# 25%            6.653465        8.485300e+06    5.363081e+07      2.916456e+05
# 50%          235.130000        1.243115e+07    3.346869e+09      1.001414e+07
# 75%          594.191164        1.520051e+07    8.075525e+09      2.834038e+07
# max        19498.683330        1.683769e+07    3.265250e+11      5.352016e+09
#
#        btc_blocks_size  btc_avg_block_size  btc_n_orphaned_blocks  \
# count      2877.000000         2906.000000            2906.000000
# mean      35505.502848            0.350366               0.364074
# std       43618.633821            0.353168               0.842259
# ...

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
# Line plot to show the trend of bitcoin market over time, note: the market price of bitcoin was low throughout the year 2010.
x = df.head(70)['Date']
y = df.head(70)['btc_market_price']
plt.plot(x,y)
plt.title('Bitcoin Market Trend over Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.show;

# %%
# Line plot to show the trend of bitcoin market over time
x = df.tail(70)['Date']
y = df.tail(70)['btc_market_price']
plt.plot(x,y)
plt.title('Bitcoin Market Trend over Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.xticks(rotation=90)
plt.show;

# %%
# sum of the market price of bitcoins per each year, note: bitcoin market started around 1st of January,2011
df.groupby('Date')['btc_market_price'].sum()
# Out:
# Date
# 1/1/2011 0:00       0.299998
# 1/1/2012 0:00       5.200000
# 1/1/2013 0:00      13.561000
# 1/1/2014 0:00     746.900000
# 1/1/2015 0:00     315.700000
#                     ...
# 9/9/2013 0:00     121.660000
# 9/9/2014 0:00     466.480000
# 9/9/2015 0:00     240.080000
# 9/9/2016 0:00     625.070900
# 9/9/2017 0:00    4375.559520
# Name: btc_market_price, Length: 2906, dtype: float64

# %%
# number of daily confirmed Bitcoin transactions over time
x = df.head(70)['Date']
y = df.head(70)['btc_n_transactions']
plt.plot(x,y)
plt.title('Bitcoin Transaction Over Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.xticks(rotation=90)
plt.show;

# %%
# a correlation between Bitcoin market capitalization and hash rate
plt.scatter(df['btc_market_cap'], df['btc_hash_rate'], c='b', marker='*')
plt.xlabel('btc_market_cap')
plt.ylabel('btc_hash_rate')
plt.title('The Relationship Between Market Capitalization and Hash rate')
plt.grid(True)
plt.show();

# %%
# the distribution of Bitcoin transaction fees 
plt.hist(df['btc_transaction_fees'], bins=30)
plt.xlabel('range')
plt.ylabel('frequency')
plt.title('Bitcoin Transaction Fees')
plt.show();

# %%
difficult_in_coin =df.groupby('Date')['btc_difficulty'].sum()
difficult_in_coin
# Out:
# Date
# 1/1/2011 0:00    1.448416e+04
# 1/1/2012 0:00    1.159929e+06
# 1/1/2013 0:00    2.979637e+06
# 1/1/2014 0:00    1.180923e+09
# 1/1/2015 0:00    4.064096e+10
#                      ...
# 9/9/2013 0:00    8.693302e+07
# 9/9/2014 0:00    2.742863e+10
# 9/9/2015 0:00    5.695765e+10
# 9/9/2016 0:00    2.207560e+11
# 9/9/2017 0:00    9.227250e+11
# Name: btc_difficulty, Length: 2906, dtype: float64

# %%
# Line plot to show how difficulty it is to find a new block change over year
b = difficult_in_coin.plot()
plt.title('Bitcoin mining difficulty over the year')
plt.xlabel('Date')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.show;

# %%
#the most active addresses on the bitcoin blockchain
sorted_df = df.sort_values(by='btc_n_unique_addresses', ascending=False)
most_active_addresses= sorted_df.head(10)['btc_n_unique_addresses']
most_active_addresses
# Out:
# 2857    1072861
# 2878    1054711
# 2849     978251
# 2856     958476
# 2858     942513
# 2877     937530
# 2861     922523
# 2883     919149
# 2881     910004
# 2842     903004
# Name: btc_n_unique_addresses, dtype: int64

# %%
#the total output volume of bitcoin transaction over time
x = df.head(70)['Date']
y = df.head(70)['btc_output_volume']
plt.plot(x,y)
plt.title('Bitcoin Volume Transaction Over Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.xticks(rotation=90)
plt.show;
